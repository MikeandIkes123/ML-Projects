# %% [markdown]
# # Part 1: Tabular Q-Learning
#
# In this part of the assignment you will familiarize yourself with the [Gymnasium API](https://gymnasium.farama.org/) for reinforcement learning and implement a tabular Q-learning agent to learn a behavioral policy in the simple [Taxi environment](https://gymnasium.farama.org/environments/toy_text/taxi/). This is intended as a warmup on a relatively small and simple task, preparing for a more challenging deep reinforcement learning task in part 2.
#
# **Learning objectives.** You will:
# 1. Install and study the standard Gymnasium API for representing a reinforcement learning environment simulation
# 2. Implement the tabular Q-learning algorithm with epsilon greedy action selection
# 3. Train an agent / compute an optimal q function and policy, experimenting with various hyperparameters like the learning rate and exploration decay
# 4. Evaluate the learning curve of average episodic return over training

# %% [markdown]
# We will use the [Gymnasium API](https://gymnasium.farama.org/) for our reinforcement learning environments. First you should run one of the following to install the necessary packages (either using `pip` or `conda` depending on your preferred Python package manager).

# %%
pip install "gymnasium[all]"
# Out:
# Requirement already satisfied: gymnasium[all] in c:\users\micha\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\micha\anaconda3\lib\site-packages (from gymnasium[all]) (1.24.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\micha\anaconda3\lib\site-packages (from gymnasium[all]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\micha\anaconda3\lib\site-packages (from gymnasium[all]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\micha\anaconda3\lib\site-packages (from gymnasium[all]) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in c:\users\micha\anaconda3\lib\site-packages (from gymnasium[all]) (0.9.0)
# Collecting box2d-py==2.3.5 (from gymnasium[all])
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pygame>=2.1.3 in c:\users\micha\anaconda3\lib\site-packages (from gymnasium[all]) (2.2.0)
# Collecting swig==4.* (from gymnasium[all])
#   Obtaining dependency information for swig==4.* from https://files.pythonhosted.org/packages/32/5a/fd3de7fa6ef45b8bb39723de65aeedbe7b213ee397d2e9fa9fefe0507636/swig-4.3.0-py2.py3-none-win_amd64.whl.metadata
#   Using cached swig-4.3.0-py2.py3-none-win_amd64.whl.metadata (3.5 kB)
# Collecting mujoco-py<2.2,>=2.1 (from gymnasium[all])
#   Obtaining dependency information for mujoco-py<2.2,>=2.1 from https://files.pythonhosted.org/packages/37/e5/e7504cb2ded511910c2a2e8f9c9e28af075850eb03a5c5a8daee5d7d9517/mujoco_py-2.1.2.14-py3-none-any.whl.metadata
#   Using cached mujoco_py-2.1.2.14-py3-none-any.whl.metadata (669 bytes)
# Collecting cython<3 (from gymnasium[all])
#   Obtaining dependency information for cython<3 from https://files.pythonhosted.org/packages/7e/26/9d8de10005fedb1eceabe713348d43bae1dbab1786042ca0751a2e2b0f8c/Cython-0.29.37-py2.py3-none-any.whl.metadata
#   Using cached Cython-0.29.37-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: mujoco>=2.1.5 in c:\users\micha\anaconda3\lib\site-packages (from gymnasium[all]) (2.3.1.post1)
# Requirement already satisfied: imageio>=2.14.1 in c:\users\micha\anaconda3\lib\site-packages (from gymnasium[all]) (2.26.0)
# Collecting jax>=0.4.0 (from gymnasium[all])
#   Obtaining dependency information for jax>=0.4.0 from https://files.pythonhosted.org/packages/62/20/6c57c50c0ccc645fea1895950f1e5cd02f961ee44b3ffe83617fa46b0c1d/jax-0.4.35-py3-none-any.whl.metadata
#   Using cached jax-0.4.35-py3-none-any.whl.metadata (22 kB)
# Collecting jaxlib>=0.4.0 (from gymnasium[all])
#   Obtaining dependency information for jaxlib>=0.4.0 from https://files.pythonhosted.org/packages/7d/7c/73a4c4a34f2bbfce63e8baefee11753b0d58a71e0d2c33f210e00edba3cb/jaxlib-0.4.35-cp311-cp311-win_amd64.whl.metadata
#   Using cached jaxlib-0.4.35-cp311-cp311-win_amd64.whl.metadata (1.0 kB)
# Collecting flax>=0.5.0 (from gymnasium[all])
#   Obtaining dependency information for flax>=0.5.0 from https://files.pythonhosted.org/packages/50/a2/daca2bc563e1fd53c33fbff1e33e84004639f7ad9e1a9a54370480a7780d/flax-0.10.2-py3-none-any.whl.metadata
#   Using cached flax-0.10.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: torch>=1.0.0 in c:\users\micha\anaconda3\lib\site-packages (from gymnasium[all]) (2.2.2)
# Requirement already satisfied: opencv-python>=3.0 in c:\users\micha\anaconda3\lib\site-packages (from gymnasium[all]) (4.10.0.84)
# Requirement already satisfied: matplotlib>=3.0 in c:\users\micha\anaconda3\lib\site-packages (from gymnasium[all]) (3.7.2)
# Requirement already satisfied: moviepy>=1.0.0 in c:\users\micha\anaconda3\lib\site-packages (from gymnasium[all]) (1.0.3)
# Requirement already satisfied: msgpack in c:\users\micha\anaconda3\lib\site-packages (from flax>=0.5.0->gymnasium[all]) (1.0.3)
# Collecting optax (from flax>=0.5.0->gymnasium[all])
#   Obtaining dependency information for optax from https://files.pythonhosted.org/packages/5c/24/28d0bb21600a78e46754947333ec9a297044af884d360092eb8561575fe9/optax-0.2.4-py3-none-any.whl.metadata
#   Using cached optax-0.2.4-py3-none-any.whl.metadata (8.3 kB)
# Collecting orbax-checkpoint (from flax>=0.5.0->gymnasium[all])
#   Obtaining dependency information for orbax-checkpoint from https://files.pythonhosted.org/packages/b3/67/a175072cd7e5a215b12f39f4d9d891881a6220d75e30ae6480d05647bdf4/orbax_checkpoint-0.10.1-py3-none-any.whl.metadata
#   Using cached orbax_checkpoint-0.10.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting tensorstore (from flax>=0.5.0->gymnasium[all])
#   Obtaining dependency information for tensorstore from https://files.pythonhosted.org/packages/1b/88/e828b97b9971cd1b71e99b2c3b154686b5ee893982f02e8886590b380ab5/tensorstore-0.1.69-cp311-cp311-win_amd64.whl.metadata
#   Using cached tensorstore-0.1.69-cp311-cp311-win_amd64.whl.metadata (3.0 kB)
# Collecting rich>=11.1 (from flax>=0.5.0->gymnasium[all])
#   Obtaining dependency information for rich>=11.1 from https://files.pythonhosted.org/packages/19/71/39c7c0d87f8d4e6c020a393182060eaefeeae6c01dab6a84ec346f2567df/rich-13.9.4-py3-none-any.whl.metadata
#   Using cached rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: PyYAML>=5.4.1 in c:\users\micha\anaconda3\lib\site-packages (from flax>=0.5.0->gymnasium[all]) (6.0)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\micha\anaconda3\lib\site-packages (from imageio>=2.14.1->gymnasium[all]) (11.0.0)
# Collecting ml-dtypes>=0.4.0 (from jax>=0.4.0->gymnasium[all])
#   Obtaining dependency information for ml-dtypes>=0.4.0 from https://files.pythonhosted.org/packages/bf/31/058b9bcf9a81abd51623985add78711a915e4b0f6045baa5f9a0b41eb039/ml_dtypes-0.5.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached ml_dtypes-0.5.0-cp311-cp311-win_amd64.whl.metadata (22 kB)
# Collecting opt-einsum (from jax>=0.4.0->gymnasium[all])
#   Obtaining dependency information for opt-einsum from https://files.pythonhosted.org/packages/23/cd/066e86230ae37ed0be70aae89aabf03ca8d9f39c8aea0dec8029455b5540/opt_einsum-3.4.0-py3-none-any.whl.metadata
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: scipy>=1.10 in c:\users\micha\anaconda3\lib\site-packages (from jax>=0.4.0->gymnasium[all]) (1.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\micha\anaconda3\lib\site-packages (from matplotlib>=3.0->gymnasium[all]) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\micha\anaconda3\lib\site-packages (from matplotlib>=3.0->gymnasium[all]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\micha\anaconda3\lib\site-packages (from matplotlib>=3.0->gymnasium[all]) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\micha\anaconda3\lib\site-packages (from matplotlib>=3.0->gymnasium[all]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\micha\anaconda3\lib\site-packages (from matplotlib>=3.0->gymnasium[all]) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\micha\anaconda3\lib\site-packages (from matplotlib>=3.0->gymnasium[all]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\micha\anaconda3\lib\site-packages (from matplotlib>=3.0->gymnasium[all]) (2.8.2)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in c:\users\micha\anaconda3\lib\site-packages (from moviepy>=1.0.0->gymnasium[all]) (5.1.1)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in c:\users\micha\anaconda3\lib\site-packages (from moviepy>=1.0.0->gymnasium[all]) (4.66.5)
# Requirement already satisfied: requests<3.0,>=2.8.1 in c:\users\micha\anaconda3\lib\site-packages (from moviepy>=1.0.0->gymnasium[all]) (2.32.3)
# Requirement already satisfied: proglog<=1.0.0 in c:\users\micha\anaconda3\lib\site-packages (from moviepy>=1.0.0->gymnasium[all]) (0.1.10)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in c:\users\micha\anaconda3\lib\site-packages (from moviepy>=1.0.0->gymnasium[all]) (0.5.1)
# Requirement already satisfied: absl-py in c:\users\micha\anaconda3\lib\site-packages (from mujoco>=2.1.5->gymnasium[all]) (2.1.0)
# Requirement already satisfied: glfw in c:\users\micha\anaconda3\lib\site-packages (from mujoco>=2.1.5->gymnasium[all]) (2.8.0)
# Requirement already satisfied: pyopengl in c:\users\micha\anaconda3\lib\site-packages (from mujoco>=2.1.5->gymnasium[all]) (3.1.6)
# Requirement already satisfied: cffi>=1.10 in c:\users\micha\anaconda3\lib\site-packages (from mujoco-py<2.2,>=2.1->gymnasium[all]) (1.15.1)
# Collecting fasteners~=0.15 (from mujoco-py<2.2,>=2.1->gymnasium[all])
#   Obtaining dependency information for fasteners~=0.15 from https://files.pythonhosted.org/packages/61/bf/fd60001b3abc5222d8eaa4a204cd8c0ae78e75adc688f33ce4bf25b7fafa/fasteners-0.19-py3-none-any.whl.metadata
#   Using cached fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: filelock in c:\users\micha\anaconda3\lib\site-packages (from torch>=1.0.0->gymnasium[all]) (3.9.0)
# Requirement already satisfied: sympy in c:\users\micha\anaconda3\lib\site-packages (from torch>=1.0.0->gymnasium[all]) (1.11.1)
# Requirement already satisfied: networkx in c:\users\micha\anaconda3\lib\site-packages (from torch>=1.0.0->gymnasium[all]) (3.1)
# Requirement already satisfied: jinja2 in c:\users\micha\anaconda3\lib\site-packages (from torch>=1.0.0->gymnasium[all]) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\micha\anaconda3\lib\site-packages (from torch>=1.0.0->gymnasium[all]) (2023.4.0)
# Requirement already satisfied: pycparser in c:\users\micha\anaconda3\lib\site-packages (from cffi>=1.10->mujoco-py<2.2,>=2.1->gymnasium[all]) (2.21)
# Requirement already satisfied: setuptools in c:\users\micha\anaconda3\lib\site-packages (from imageio-ffmpeg>=0.2.0->moviepy>=1.0.0->gymnasium[all]) (75.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\micha\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0->gymnasium[all]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\micha\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gymnasium[all]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\micha\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gymnasium[all]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\micha\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gymnasium[all]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\micha\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gymnasium[all]) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\micha\anaconda3\lib\site-packages (from rich>=11.1->flax>=0.5.0->gymnasium[all]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\micha\anaconda3\lib\site-packages (from rich>=11.1->flax>=0.5.0->gymnasium[all]) (2.15.1)
# Requirement already satisfied: colorama in c:\users\micha\anaconda3\lib\site-packages (from tqdm<5.0,>=4.11.2->moviepy>=1.0.0->gymnasium[all]) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\micha\anaconda3\lib\site-packages (from jinja2->torch>=1.0.0->gymnasium[all]) (2.1.1)
# Collecting chex>=0.1.87 (from optax->flax>=0.5.0->gymnasium[all])
#   Obtaining dependency information for chex>=0.1.87 from https://files.pythonhosted.org/packages/46/dd/c1ff2eb8fbf95a8ca804abb1cc3ce70b283ee7b4bc653c3abac245670400/chex-0.1.87-py3-none-any.whl.metadata
#   Using cached chex-0.1.87-py3-none-any.whl.metadata (17 kB)
# Collecting etils[epy] (from optax->flax>=0.5.0->gymnasium[all])
#   Obtaining dependency information for etils[epy] from https://files.pythonhosted.org/packages/4f/4a/ff8aa2c57300613b69905308c5afe92c5b01112d766c25a305fd6796170a/etils-1.11.0-py3-none-any.whl.metadata
#   Using cached etils-1.11.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: nest_asyncio in c:\users\micha\anaconda3\lib\site-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (1.5.6)
# Requirement already satisfied: protobuf in c:\users\micha\anaconda3\lib\site-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (5.28.2)
# Collecting humanize (from orbax-checkpoint->flax>=0.5.0->gymnasium[all])
#   Obtaining dependency information for humanize from https://files.pythonhosted.org/packages/92/75/4bc3e242ad13f2e6c12e0b0401ab2c5e5c6f0d7da37ec69bc808e24e0ccb/humanize-4.11.0-py3-none-any.whl.metadata
#   Using cached humanize-4.11.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting simplejson>=3.16.0 (from orbax-checkpoint->flax>=0.5.0->gymnasium[all])
#   Obtaining dependency information for simplejson>=3.16.0 from https://files.pythonhosted.org/packages/65/be/d8ab9717f471be3c114f16abd8be21d9a6a0a09b9b49177d93d64d3717d9/simplejson-3.19.3-cp311-cp311-win_amd64.whl.metadata
#   Using cached simplejson-3.19.3-cp311-cp311-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: mpmath>=0.19 in c:\users\micha\anaconda3\lib\site-packages (from sympy->torch>=1.0.0->gymnasium[all]) (1.3.0)
# Requirement already satisfied: toolz>=0.9.0 in c:\users\micha\anaconda3\lib\site-packages (from chex>=0.1.87->optax->flax>=0.5.0->gymnasium[all]) (0.12.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\micha\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.5.0->gymnasium[all]) (0.1.0)
# Requirement already satisfied: importlib_resources in c:\users\micha\anaconda3\lib\site-packages (from etils[epy]->optax->flax>=0.5.0->gymnasium[all]) (6.4.5)
# Requirement already satisfied: zipp in c:\users\micha\anaconda3\lib\site-packages (from etils[epy]->optax->flax>=0.5.0->gymnasium[all]) (3.11.0)
# Using cached swig-4.3.0-py2.py3-none-win_amd64.whl (2.6 MB)
# Using cached Cython-0.29.37-py2.py3-none-any.whl (989 kB)
# Using cached flax-0.10.2-py3-none-any.whl (424 kB)
# Using cached jax-0.4.35-py3-none-any.whl (2.2 MB)
# Using cached jaxlib-0.4.35-cp311-cp311-win_amd64.whl (56.5 MB)
# Using cached mujoco_py-2.1.2.14-py3-none-any.whl (2.4 MB)
# Using cached fasteners-0.19-py3-none-any.whl (18 kB)
# Using cached ml_dtypes-0.5.0-cp311-cp311-win_amd64.whl (211 kB)
# Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Using cached optax-0.2.4-py3-none-any.whl (319 kB)
# Using cached orbax_checkpoint-0.10.1-py3-none-any.whl (328 kB)
# Using cached tensorstore-0.1.69-cp311-cp311-win_amd64.whl (12.0 MB)
# Using cached chex-0.1.87-py3-none-any.whl (99 kB)
# Using cached simplejson-3.19.3-cp311-cp311-win_amd64.whl (75 kB)
# Using cached humanize-4.11.0-py3-none-any.whl (128 kB)
# Using cached etils-1.11.0-py3-none-any.whl (165 kB)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py): started
#   Building wheel for box2d-py (setup.py): finished with status 'error'
#   Running setup.py clean for box2d-py
# Failed to build box2d-py
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping C:\Users\micha\anaconda3\Lib\site-packages\scipy-1.12.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\micha\anaconda3\Lib\site-packages\scipy-1.12.0.dist-info due to invalid metadata entry 'name'
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [16 lines of output]
#   Using setuptools (version 75.2.0).
#   C:\Users\micha\anaconda3\Lib\site-packages\setuptools\_distutils\dist.py:261: UserWarning: Unknown distribution option: 'test_suite'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib.win-amd64-cpython-311\Box2D
#   copying library\Box2D\Box2D.py -> build\lib.win-amd64-cpython-311\Box2D
#   copying library\Box2D\__init__.py -> build\lib.win-amd64-cpython-311\Box2D
#   creating build\lib.win-amd64-cpython-311\Box2D\b2
#   copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-cpython-311\Box2D\b2
#   running build_ext
#   building 'Box2D._Box2D' extension
#   swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#   swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#   error: command 'swig.exe' failed: None
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for box2d-py
# ERROR: Could not build wheels for box2d-py, which is required to install pyproject.toml-based projects
# WARNING: Skipping C:\Users\micha\anaconda3\Lib\site-packages\scipy-1.12.0.dist-info due to invalid metadata entry 'name'

# %%
conda install -c conda-forge gymnasium-all
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.11.0
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: ...working... unsuccessful attempt using repodata from current_repodata.json, retrying with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\micha\anaconda3
#
#   added / updated specs:
#     - gymnasium-all
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     absl-py-2.1.0              |     pyhd8ed1ab_0         105 KB  conda-forge
#     ale-py-0.9.0               |  py311hde19ee9_0         914 KB  conda-forge
#     aom-3.6.1                  |       h63175ca_0         7.6 MB  conda-forge
#     box2d-py-2.3.8             |  py311hda3d55a_9         374 KB  conda-forge
#     ca-certificates-2024.8.30  |       h56e8100_0         155 KB  conda-forge
#     cairo-1.16.0               |    hd694305_1014         2.3 MB  conda-forge
#     certifi-2024.8.30          |     pyhd8ed1ab_0         160 KB  conda-forge
#     conda-23.7.4               |  py311h1ea47a8_0         1.3 MB  conda-forge
#     dask-2.10.1                |             py_0          13 KB
#     dask-core-2.10.1           |             py_0         562 KB
#     dataclasses-0.8            |     pyhc8e2a94_3          10 KB  conda-forge
#     distributed-2.10.0         |             py_0         408 KB
#     expat-2.6.4                |       he0c23c2_0         225 KB  conda-forge
#     farama-notifications-0.0.4 |     pyhd8ed1ab_0           8 KB  conda-forge
#     ffmpeg-5.1.2               | gpl_h8bb4bc8_112        10.8 MB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.14.2          |       hbde0cde_0         186 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     freeglut-3.2.2             |       he0c23c2_3         109 KB  conda-forge
#     gettext-0.22.5             |       h5728263_3          33 KB  conda-forge
#     gettext-tools-0.22.5       |       h5a7288d_3         3.3 MB  conda-forge
#     glfw-3.4                   |       hcfcfb64_0         116 KB  conda-forge
#     glib-2.78.4                |       h12be248_0         494 KB  conda-forge
#     glib-tools-2.78.4          |       h12be248_0         143 KB  conda-forge
#     graphite2-1.3.13           |    h63175ca_1003          93 KB  conda-forge
#     gst-plugins-base-1.22.9    |       h001b923_1         1.9 MB  conda-forge
#     gstreamer-1.22.9           |       hb4038d2_1         1.8 MB  conda-forge
#     gymnasium-1.0.0            |  py311h06a5be4_1         1.1 MB  conda-forge
#     gymnasium-all-1.0.0        |  py311haabb6a8_1          75 KB  conda-forge
#     gymnasium-atari-1.0.0      |  py311h1ea47a8_1           9 KB  conda-forge
#     gymnasium-box2d-1.0.0      |  py311h1ea47a8_1           9 KB  conda-forge
#     gymnasium-classic_control-1.0.0|  py311h1ea47a8_1           9 KB  conda-forge
#     gymnasium-mujoco-1.0.0     |  py311h1ea47a8_1           9 KB  conda-forge
#     gymnasium-other-1.0.0      |  py311h1ea47a8_1           9 KB  conda-forge
#     gymnasium-toy_text-1.0.0   |  py311h1ea47a8_1           9 KB  conda-forge
#     harfbuzz-6.0.0             |       he256f1b_0         875 KB  conda-forge
#     icu-70.1                   |       h0e60522_0        17.0 MB  conda-forge
#     imageio-ffmpeg-0.5.1       |     pyhd8ed1ab_0          20 KB  conda-forge
#     importlib-resources-6.4.5  |     pyhd8ed1ab_0           9 KB  conda-forge
#     importlib_resources-6.4.5  |     pyhd8ed1ab_0          32 KB  conda-forge
#     jasper-2.0.33              |       hc2e4405_1         614 KB  conda-forge
#     jax-jumpy-1.0.0            |     pyhd8ed1ab_0          20 KB  conda-forge
#     libarchive-3.6.2           |       h6f8411a_1         938 KB  conda-forge
#     libasprintf-0.22.5         |       h5728263_3          49 KB  conda-forge
#     libasprintf-devel-0.22.5   |       h5728263_3          35 KB  conda-forge
#     libblas-3.9.0              |1_h8933c1f_netlib         193 KB  conda-forge
#     libcblas-3.9.0             |8_h719fc58_netlib          48 KB  conda-forge
#     libccd-double-2.1          |       h63175ca_3          36 KB  conda-forge
#     libclang-15.0.7            |default_h3a3e6c3_5         145 KB  conda-forge
#     libclang13-15.0.7          |default_hf64faad_5        20.9 MB  conda-forge
#     libexpat-2.6.4             |       he0c23c2_0         136 KB  conda-forge
#     libflac-1.4.3              |       h63175ca_0         323 KB  conda-forge
#     libgettextpo-0.22.5        |       h5728263_3         167 KB  conda-forge
#     libgettextpo-devel-0.22.5  |       h5728263_3          39 KB  conda-forge
#     libglib-2.78.4             |       h16e383f_0         2.5 MB  conda-forge
#     libiconv-1.17              |       hcfcfb64_2         621 KB  conda-forge
#     libintl-0.22.5             |       h5728263_3          93 KB  conda-forge
#     libintl-devel-0.22.5       |       h5728263_3          40 KB  conda-forge
#     liblapack-3.9.0            |8_h719fc58_netlib         1.9 MB  conda-forge
#     liblapacke-3.9.0           |8_h719fc58_netlib         392 KB  conda-forge
#     libmad-0.15.1b             |    hcfcfb64_1001          91 KB  conda-forge
#     libogg-1.3.5               |       h2466b09_0          35 KB  conda-forge
#     libopencv-4.7.0            |  py311h0442f2a_1        31.0 MB  conda-forge
#     libopus-1.3.1              |       h8ffe710_1         255 KB  conda-forge
#     libprotobuf-3.21.12        |       h12be248_2         2.0 MB  conda-forge
#     libsqlite-3.47.0           |       h2466b09_1         871 KB  conda-forge
#     libvorbis-1.3.7            |       h0e60522_0         267 KB  conda-forge
#     libxml2-2.12.7             |       h283a6d9_1         1.6 MB  conda-forge
#     libxslt-1.1.39             |       h3df6e99_0         409 KB  conda-forge
#     libzlib-1.2.13             |       h2466b09_6          55 KB  conda-forge
#     lodepng-20220109           |       h2d74725_0          94 KB  conda-forge
#     lxml-5.2.2                 |  py311h12967d8_0         1.0 MB  conda-forge
#     m2w64-gcc-libgfortran-5.3.0|                6         342 KB  conda-forge
#     m2w64-gcc-libs-5.3.0       |                7         520 KB  conda-forge
#     m2w64-gcc-libs-core-5.3.0  |                7         214 KB  conda-forge
#     m2w64-gmp-6.1.0            |                2         726 KB  conda-forge
#     moviepy-1.0.3              |     pyhd8ed1ab_1          78 KB  conda-forge
#     mpg123-1.32.9              |       h01009b0_0         268 KB  conda-forge
#     mujoco-cxx-2.3.1.post1     |       hf76cbab_0         3.4 MB  conda-forge
#     mujoco-python-2.3.1.post1  |  py311h8eda8e3_0         1.0 MB  conda-forge
#     openh264-2.3.1             |       h63175ca_2         401 KB  conda-forge
#     openssl-3.4.0              |       h2466b09_0         8.1 MB  conda-forge
#     pixman-0.43.4              |       h63175ca_0         451 KB  conda-forge
#     portmidi-2.0.4             |       h63175ca_2          44 KB  conda-forge
#     proglog-0.1.10             |     pyhaa61c55_0          12 KB  conda-forge
#     py-opencv-4.7.0            |  py311h3810d55_1         1.1 MB  conda-forge
#     pygame-2.2.0               |  py311h6ef553b_0         2.6 MB  conda-forge
#     pyglfw-2.8.0               |     pyha770c72_0          30 KB  conda-forge
#     pyopengl-3.1.6             |     pyhd8ed1ab_1         867 KB  conda-forge
#     python_abi-3.11            |          2_cp311           5 KB  conda-forge
#     qhull-2020.2               |       hc790b64_5         1.3 MB  conda-forge
#     qt-main-5.15.8             |       h720456b_6        57.6 MB  conda-forge
#     qtwebkit-5.212             |       h992fabe_8        10.3 MB  conda-forge
#     sacremoses-0.0.53          |     pyhd8ed1ab_0         427 KB  conda-forge
#     sdl2-2.30.7                |       he0c23c2_0         2.1 MB  conda-forge
#     sdl2_image-2.6.3           |       h090e09f_0         111 KB  conda-forge
#     sdl2_mixer-2.6.3           |       he8f0768_1         167 KB  conda-forge
#     sdl2_ttf-2.20.2            |       h41be9cf_0          47 KB  conda-forge
#     svt-av1-1.4.1              |       h63175ca_0         1.9 MB  conda-forge
#     tinyxml2-9.0.0             |       h0e60522_2         122 KB  conda-forge
#     transformers-4.17.0        |     pyhd8ed1ab_0         1.9 MB  conda-forge
#     ucrt-10.0.22621.0          |       h57928b3_1         547 KB  conda-forge
#     vc14_runtime-14.42.34433   |      he29a5d6_23         737 KB  conda-forge
#     vs2015_runtime-14.42.34433 |      hdffcdeb_23          17 KB  conda-forge
#     x264-1!164.3095            |       h8ffe710_2        1017 KB  conda-forge
#     x265-3.5                   |       h2d74725_3         5.3 MB  conda-forge
#     zlib-1.2.13                |       h2466b09_6         105 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       225.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   absl-py            conda-forge/noarch::absl-py-2.1.0-pyhd8ed1ab_0
#   ale-py             conda-forge/win-64::ale-py-0.9.0-py311hde19ee9_0
#   box2d-py           conda-forge/win-64::box2d-py-2.3.8-py311hda3d55a_9
#   cairo              conda-forge/win-64::cairo-1.16.0-hd694305_1014
#   dataclasses        conda-forge/noarch::dataclasses-0.8-pyhc8e2a94_3
#   expat              conda-forge/win-64::expat-2.6.4-he0c23c2_0
#   farama-notificati~ conda-forge/noarch::farama-notifications-0.0.4-pyhd8ed1ab_0
#   ffmpeg             conda-forge/win-64::ffmpeg-5.1.2-gpl_h8bb4bc8_112
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/win-64::fontconfig-2.14.2-hbde0cde_0
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   freeglut           conda-forge/win-64::freeglut-3.2.2-he0c23c2_3
#   gettext            conda-forge/win-64::gettext-0.22.5-h5728263_3
#   gettext-tools      conda-forge/win-64::gettext-tools-0.22.5-h5a7288d_3
#   glfw               conda-forge/win-64::glfw-3.4-hcfcfb64_0
#   glib-tools         conda-forge/win-64::glib-tools-2.78.4-h12be248_0
#   graphite2          conda-forge/win-64::graphite2-1.3.13-h63175ca_1003
#   gst-plugins-base   conda-forge/win-64::gst-plugins-base-1.22.9-h001b923_1
#   gstreamer          conda-forge/win-64::gstreamer-1.22.9-hb4038d2_1
#   gymnasium          conda-forge/win-64::gymnasium-1.0.0-py311h06a5be4_1
#   gymnasium-all      conda-forge/win-64::gymnasium-all-1.0.0-py311haabb6a8_1
#   gymnasium-atari    conda-forge/win-64::gymnasium-atari-1.0.0-py311h1ea47a8_1
#   gymnasium-box2d    conda-forge/win-64::gymnasium-box2d-1.0.0-py311h1ea47a8_1
#   gymnasium-classic~ conda-forge/win-64::gymnasium-classic_control-1.0.0-py311h1ea47a8_1
#   gymnasium-mujoco   conda-forge/win-64::gymnasium-mujoco-1.0.0-py311h1ea47a8_1
#   gymnasium-other    conda-forge/win-64::gymnasium-other-1.0.0-py311h1ea47a8_1
#   gymnasium-toy_text conda-forge/win-64::gymnasium-toy_text-1.0.0-py311h1ea47a8_1
#   harfbuzz           conda-forge/win-64::harfbuzz-6.0.0-he256f1b_0
#   imageio-ffmpeg     conda-forge/noarch::imageio-ffmpeg-0.5.1-pyhd8ed1ab_0
#   importlib-resourc~ conda-forge/noarch::importlib-resources-6.4.5-pyhd8ed1ab_0
#   importlib_resourc~ conda-forge/noarch::importlib_resources-6.4.5-pyhd8ed1ab_0
#   jasper             conda-forge/win-64::jasper-2.0.33-hc2e4405_1
#   jax-jumpy          conda-forge/noarch::jax-jumpy-1.0.0-pyhd8ed1ab_0
#   libasprintf        conda-forge/win-64::libasprintf-0.22.5-h5728263_3
#   libasprintf-devel  conda-forge/win-64::libasprintf-devel-0.22.5-h5728263_3
#   libblas            conda-forge/win-64::libblas-3.9.0-1_h8933c1f_netlib
#   libcblas           conda-forge/win-64::libcblas-3.9.0-8_h719fc58_netlib
#   libccd-double      conda-forge/win-64::libccd-double-2.1-h63175ca_3
#   libexpat           conda-forge/win-64::libexpat-2.6.4-he0c23c2_0
#   libflac            conda-forge/win-64::libflac-1.4.3-h63175ca_0
#   libgettextpo       conda-forge/win-64::libgettextpo-0.22.5-h5728263_3
#   libgettextpo-devel conda-forge/win-64::libgettextpo-devel-0.22.5-h5728263_3
#   libglib            conda-forge/win-64::libglib-2.78.4-h16e383f_0
#   libintl            conda-forge/win-64::libintl-0.22.5-h5728263_3
#   libintl-devel      conda-forge/win-64::libintl-devel-0.22.5-h5728263_3
#   liblapack          conda-forge/win-64::liblapack-3.9.0-8_h719fc58_netlib
#   liblapacke         conda-forge/win-64::liblapacke-3.9.0-8_h719fc58_netlib
#   libmad             conda-forge/win-64::libmad-0.15.1b-hcfcfb64_1001
#   libogg             conda-forge/win-64::libogg-1.3.5-h2466b09_0
#   libopencv          conda-forge/win-64::libopencv-4.7.0-py311h0442f2a_1
#   libopus            conda-forge/win-64::libopus-1.3.1-h8ffe710_1
#   libsqlite          conda-forge/win-64::libsqlite-3.47.0-h2466b09_1
#   libvorbis          conda-forge/win-64::libvorbis-1.3.7-h0e60522_0
#   libzlib            conda-forge/win-64::libzlib-1.2.13-h2466b09_6
#   lodepng            conda-forge/win-64::lodepng-20220109-h2d74725_0
#   m2w64-gcc-libgfor~ conda-forge/win-64::m2w64-gcc-libgfortran-5.3.0-6
#   m2w64-gcc-libs     conda-forge/win-64::m2w64-gcc-libs-5.3.0-7
#   m2w64-gcc-libs-co~ conda-forge/win-64::m2w64-gcc-libs-core-5.3.0-7
#   m2w64-gmp          conda-forge/win-64::m2w64-gmp-6.1.0-2
#   moviepy            conda-forge/noarch::moviepy-1.0.3-pyhd8ed1ab_1
#   mpg123             conda-forge/win-64::mpg123-1.32.9-h01009b0_0
#   mujoco-cxx         conda-forge/win-64::mujoco-cxx-2.3.1.post1-hf76cbab_0
#   mujoco-python      conda-forge/win-64::mujoco-python-2.3.1.post1-py311h8eda8e3_0
#   openh264           conda-forge/win-64::openh264-2.3.1-h63175ca_2
#   pixman             conda-forge/win-64::pixman-0.43.4-h63175ca_0
#   portmidi           conda-forge/win-64::portmidi-2.0.4-h63175ca_2
#   proglog            conda-forge/noarch::proglog-0.1.10-pyhaa61c55_0
#   py-opencv          conda-forge/win-64::py-opencv-4.7.0-py311h3810d55_1
#   pygame             conda-forge/win-64::pygame-2.2.0-py311h6ef553b_0
#   pyglfw             conda-forge/noarch::pyglfw-2.8.0-pyha770c72_0
#   pyopengl           conda-forge/noarch::pyopengl-3.1.6-pyhd8ed1ab_1
#   python_abi         conda-forge/win-64::python_abi-3.11-2_cp311
#   qhull              conda-forge/win-64::qhull-2020.2-hc790b64_5
#   sacremoses         conda-forge/noarch::sacremoses-0.0.53-pyhd8ed1ab_0
#   sdl2               conda-forge/win-64::sdl2-2.30.7-he0c23c2_0
#   sdl2_image         conda-forge/win-64::sdl2_image-2.6.3-h090e09f_0
#   sdl2_mixer         conda-forge/win-64::sdl2_mixer-2.6.3-he8f0768_1
#   sdl2_ttf           conda-forge/win-64::sdl2_ttf-2.20.2-h41be9cf_0
#   svt-av1            conda-forge/win-64::svt-av1-1.4.1-h63175ca_0
#   tinyxml2           conda-forge/win-64::tinyxml2-9.0.0-h0e60522_2
#   ucrt               conda-forge/win-64::ucrt-10.0.22621.0-h57928b3_1
#   vc14_runtime       conda-forge/win-64::vc14_runtime-14.42.34433-he29a5d6_23
#   x264               conda-forge/win-64::x264-1!164.3095-h8ffe710_2
#   x265               conda-forge/win-64::x265-3.5-h2d74725_3
#
# The following packages will be REMOVED:
#
#   arrow-cpp-11.0.0-ha81ea56_2
#   datasets-2.12.0-py311haa95532_0
#   grpc-cpp-1.48.2-hfe90ff0_1
#   orc-1.7.4-h623e30f_1
#   pyarrow-11.0.0-py311h8a3a540_1
#
# The following packages will be UPDATED:
#
#   aom                       pkgs/main::aom-3.6.0-hd77b12b_0 --> conda-forge::aom-3.6.1-h63175ca_0
#   ca-certificates    pkgs/main::ca-certificates-2024.3.11-~ --> conda-forge::ca-certificates-2024.8.30-h56e8100_0
#   certifi            pkgs/main/win-64::certifi-2024.2.2-py~ --> conda-forge/noarch::certifi-2024.8.30-pyhd8ed1ab_0
#   glib                    pkgs/main::glib-2.69.1-h5dc1a3c_2 --> conda-forge::glib-2.78.4-h12be248_0
#   icu                        pkgs/main::icu-58.2-ha925a31_3 --> conda-forge::icu-70.1-h0e60522_0
#   libclang           pkgs/main::libclang-14.0.6-default_hb~ --> conda-forge::libclang-15.0.7-default_h3a3e6c3_5
#   libclang13         pkgs/main::libclang13-14.0.6-default_~ --> conda-forge::libclang13-15.0.7-default_hf64faad_5
#   libiconv              pkgs/main::libiconv-1.16-h2bbff1b_2 --> conda-forge::libiconv-1.17-hcfcfb64_2
#   libprotobuf        pkgs/main::libprotobuf-3.20.3-h23ce68~ --> conda-forge::libprotobuf-3.21.12-h12be248_2
#   libxml2              pkgs/main::libxml2-2.10.4-h0ad7f3c_1 --> conda-forge::libxml2-2.12.7-h283a6d9_1
#   libxslt              pkgs/main::libxslt-1.1.37-h2bbff1b_1 --> conda-forge::libxslt-1.1.39-h3df6e99_0
#   lxml                pkgs/main::lxml-4.9.3-py311h09808a7_0 --> conda-forge::lxml-5.2.2-py311h12967d8_0
#   openssl              pkgs/main::openssl-3.0.13-h2bbff1b_0 --> conda-forge::openssl-3.4.0-h2466b09_0
#   qt-main              pkgs/main::qt-main-5.15.2-h879a1e9_9 --> conda-forge::qt-main-5.15.8-h720456b_6
#   qtwebkit             pkgs/main::qtwebkit-5.212-h2bbfb41_5 --> conda-forge::qtwebkit-5.212-h992fabe_8
#   vs2015_runtime     pkgs/main::vs2015_runtime-14.27.29016~ --> conda-forge::vs2015_runtime-14.42.34433-hdffcdeb_23
#   zlib                    pkgs/main::zlib-1.2.13-h8cc25b3_0 --> conda-forge::zlib-1.2.13-h2466b09_6
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda              pkgs/main::conda-23.7.4-py311haa95532~ --> conda-forge::conda-23.7.4-py311h1ea47a8_0
#   dask               pkgs/main/win-64::dask-2023.6.0-py311~ --> pkgs/main/noarch::dask-2.10.1-py_0
#   dask-core          pkgs/main/win-64::dask-core-2023.6.0-~ --> pkgs/main/noarch::dask-core-2.10.1-py_0
#   distributed        pkgs/main/win-64::distributed-2023.6.~ --> pkgs/main/noarch::distributed-2.10.0-py_0
#   libarchive         pkgs/main::libarchive-3.6.2-hb62f4d4_2 --> conda-forge::libarchive-3.6.2-h6f8411a_1
#   transformers       pkgs/main/win-64::transformers-4.32.1~ --> conda-forge/noarch::transformers-4.17.0-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
#
# libclang-15.0.7      | 145 KB    |            |   0%
#
# libmad-0.15.1b       | 91 KB     |            |   0%
#
#
# fonts-conda-forge-1  | 4 KB      |            |   0%
#
#
#
# pixman-0.43.4        | 451 KB    |            |   0%
#
#
#
#
# icu-70.1             | 17.0 MB   |            |   0%
#
#
#
#
#
# m2w64-gmp-6.1.0      | 726 KB    |            |   0%
#
#
#
#
#
#
# dask-core-2.10.1     | 562 KB    |            |   0%
#
#
#
#
#
#
#
# gstreamer-1.22.9     | 1.8 MB    |            |   0%
#
#
#
#
#
#
#
#
# ucrt-10.0.22621.0    | 547 KB    |            |   0%
#
#
#
#
#
#
#
#
#
# importlib-resources- | 9 KB      |            |   0%
#
#
#
#
#
#
#
#
#
#
# python_abi-3.11      | 5 KB      |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# dataclasses-0.8      | 10 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mujoco-python-2.3.1. | 1.0 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.78.4          | 494 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-3.21.12  | 2.0 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jasper-2.0.33        | 614 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libasprintf-devel-0. | 35 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# pixman-0.43.4        | 451 KB    | 3          |   4%
# libclang-15.0.7      | 145 KB    | #1         |  11%
#
#
# fonts-conda-forge-1  | 4 KB      | ########## | 100%
#
# libmad-0.15.1b       | 91 KB     | #7         |  18%
#
#
#
#
# icu-70.1             | 17.0 MB   |            |   0%
#
#
# fonts-conda-forge-1  | 4 KB      | ########## | 100%
#
#
#
#
#
# m2w64-gmp-6.1.0      | 726 KB    | 2          |   2%
#
# libmad-0.15.1b       | 91 KB     | ########## | 100%
#
# libmad-0.15.1b       | 91 KB     | ########## | 100%
#
#
#
#
#
#
#
# gstreamer-1.22.9     | 1.8 MB    |            |   1%
#
#
#
#
# icu-70.1             | 17.0 MB   | 2          |   3%
#
#
#
# pixman-0.43.4        | 451 KB    | ########## | 100%
#
#
#
# pixman-0.43.4        | 451 KB    | ########## | 100%
# libclang-15.0.7      | 145 KB    | ########## | 100%
# libclang-15.0.7      | 145 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# ucrt-10.0.22621.0    | 547 KB    | 2          |   3%
#
#
#
#
#
# m2w64-gmp-6.1.0      | 726 KB    | #####2     |  53%
#
#
#
#
# icu-70.1             | 17.0 MB   | 5          |   6%
#
#
#
#
#
#
#
#
# ucrt-10.0.22621.0    | 547 KB    | ######1    |  61%
#
#
#
#
#
#
#
# gstreamer-1.22.9     | 1.8 MB    | #2         |  13%
#
#
#
#
#
# m2w64-gmp-6.1.0      | 726 KB    | #########  |  90%
#
#
#
#
# icu-70.1             | 17.0 MB   | 8          |   9%
#
#
#
#
#
#
# dask-core-2.10.1     | 562 KB    | 2          |   3%
#
#
#
#
#
#
#
# gstreamer-1.22.9     | 1.8 MB    | ####1      |  41%
#
#
#
#
# icu-70.1             | 17.0 MB   | #1         |  12%
#
#
#
#
#
#
# dask-core-2.10.1     | 562 KB    | ####8      |  48%
#
#
#
#
#
#
#
#
#
#
# python_abi-3.11      | 5 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
# importlib-resources- | 9 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# python_abi-3.11      | 5 KB      | ########## | 100%
#
#
#
#
#
#
#
# gstreamer-1.22.9     | 1.8 MB    | #####6     |  57%
#
#
#
#
#
#
#
#
#
# importlib-resources- | 9 KB      | ########## | 100%
#
#
#
#
# icu-70.1             | 17.0 MB   | #4         |  15%
#
#
#
#
#
#
#
#
# ucrt-10.0.22621.0    | 547 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# ucrt-10.0.22621.0    | 547 KB    | ########## | 100%
#
#
#
#
#
# m2w64-gmp-6.1.0      | 726 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# dataclasses-0.8      | 10 KB     | ########## | 100%
#
#
#
#
#
#
#
# gstreamer-1.22.9     | 1.8 MB    | ########2  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# dataclasses-0.8      | 10 KB     | ########## | 100%
#
#
#
#
# icu-70.1             | 17.0 MB   | #7         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | 5          |   6%
#
#
#
#
# icu-70.1             | 17.0 MB   | ##1        |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.78.4          | 494 KB    | 3          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mujoco-python-2.3.1. | 1.0 MB    | 1          |   1%
#
#
#
#
# icu-70.1             | 17.0 MB   | ##4        |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-3.21.12  | 2.0 MB    |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | #2         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mujoco-python-2.3.1. | 1.0 MB    | #1         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   |            |   0%
#
#
#
#
# icu-70.1             | 17.0 MB   | ##7        |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-3.21.12  | 2.0 MB    | ##4        |  24%
#
#
#
#
#
#
# dask-core-2.10.1     | 562 KB    | ########## | 100%
#
#
#
#
#
#
# dask-core-2.10.1     | 562 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mujoco-python-2.3.1. | 1.0 MB    | ##3        |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-3.21.12  | 2.0 MB    | ####7      |  48%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | #5         |  15%
#
#
#
#
# icu-70.1             | 17.0 MB   | ###        |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mujoco-python-2.3.1. | 1.0 MB    | ####4      |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-3.21.12  | 2.0 MB    | ######4    |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | 1          |   2%
#
#
#
#
# icu-70.1             | 17.0 MB   | ###2       |  32%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | #7         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mujoco-python-2.3.1. | 1.0 MB    | ######8    |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-3.21.12  | 2.0 MB    | ########6  |  86%
#
#
#
#
# icu-70.1             | 17.0 MB   | ###4       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | 2          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | ##         |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mujoco-python-2.3.1. | 1.0 MB    | ########9  |  90%
#
#
#
#
# icu-70.1             | 17.0 MB   | ###7       |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | 3          |   4%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | ##2        |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jasper-2.0.33        | 614 KB    | 2          |   3%
#
#
#
#
# icu-70.1             | 17.0 MB   | ###9       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | 4          |   5%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | ##4        |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jasper-2.0.33        | 614 KB    | #######5   |  76%
#
#
#
#
# icu-70.1             | 17.0 MB   | ####2      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libasprintf-devel-0. | 35 KB     | ####5      |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | 5          |   5%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | ##7        |  27%
#
#
#
#
# icu-70.1             | 17.0 MB   | ####4      |  45%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | ###        |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | 6          |   6%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | ###3       |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | 6          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# icu-70.1             | 17.0 MB   | ####6      |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | ###6       |  36%
#
#
#
#
# icu-70.1             | 17.0 MB   | ####8      |  49%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | ###9       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | 8          |   8%
#
#
#
#
# icu-70.1             | 17.0 MB   | #####      |  51%
#
#
#
#
#
#
#
# gstreamer-1.22.9     | 1.8 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | ####2      |  43%
#
#
#
#
# icu-70.1             | 17.0 MB   | #####2     |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | ####5      |  46%
#
#
#
#
# icu-70.1             | 17.0 MB   | #####4     |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-3.21.12  | 2.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #1         |  11%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | ####8      |  49%
#
#
#
#
# icu-70.1             | 17.0 MB   | #####5     |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #2         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | #####2     |  52%
#
#
#
#
# icu-70.1             | 17.0 MB   | #####8     |  58%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | #####5     |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #3         |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mujoco-python-2.3.1. | 1.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.78.4          | 494 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.78.4          | 494 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jasper-2.0.33        | 614 KB    | ########## | 100%
#
#
#
#
# icu-70.1             | 17.0 MB   | ######     |  61%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | #####8     |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libasprintf-devel-0. | 35 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #4         |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libasprintf-devel-0. | 35 KB     | ########## | 100%
#
#
#
#
# icu-70.1             | 17.0 MB   | ######3    |  63%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | ######1    |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #4         |  15%
#
#
#
#
# icu-70.1             | 17.0 MB   | ######5    |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #6         |  16%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | ######7    |  67%
#
#
#
#
# icu-70.1             | 17.0 MB   | ######6    |  67%
#
#
#
#
# icu-70.1             | 17.0 MB   | ######8    |  69%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | #######    |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #6         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | #######3   |  74%
#
#
#
#
# icu-70.1             | 17.0 MB   | #######    |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #7         |  18%
#
#
#
#
# icu-70.1             | 17.0 MB   | #######2   |  72%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | #######6   |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #8         |  18%
#
#
#
#
# icu-70.1             | 17.0 MB   | #######3   |  74%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | #######9   |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #9         |  19%
#
#
#
#
# icu-70.1             | 17.0 MB   | #######5   |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #9         |  20%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | ########2  |  83%
#
#
#
#
# icu-70.1             | 17.0 MB   | #######7   |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ##         |  20%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | ########5  |  86%
#
#
#
#
# icu-70.1             | 17.0 MB   | #######8   |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ##1        |  21%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | ########8  |  88%
#
#
#
#
# icu-70.1             | 17.0 MB   | ########   |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ##1        |  22%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | #########1 |  92%
#
#
#
#
# icu-70.1             | 17.0 MB   | ########2  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ##2        |  23%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | #########4 |  94%
#
#
#
#
# icu-70.1             | 17.0 MB   | ########3  |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ##3        |  23%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | #########7 |  97%
#
#
#
#
# icu-70.1             | 17.0 MB   | ########5  |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ##3        |  24%
#
#
#
#
# icu-70.1             | 17.0 MB   | ########6  |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ##4        |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ##5        |  25%
#
#
#
#
# icu-70.1             | 17.0 MB   | ########9  |  89%
#
#
#
#
# icu-70.1             | 17.0 MB   | #########  |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ##6        |  26%
#
#
#
#
# icu-70.1             | 17.0 MB   | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ##6        |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ##7        |  28%
#
#
#
#
# icu-70.1             | 17.0 MB   | #########4 |  94%
#
#
#
#
# icu-70.1             | 17.0 MB   | #########5 |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ##8        |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ##9        |  29%
#
#
#
#
# icu-70.1             | 17.0 MB   | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ##9        |  30%
#
#
#
#
# icu-70.1             | 17.0 MB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ###        |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ###1       |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ###2       |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ###3       |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ###4       |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ###5       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ###6       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ###7       |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ###7       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ###8       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ###9       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-5.1.2         | 10.8 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ####       |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ####1      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ####2      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ####3      |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ####4      |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ####5      |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ####6      |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ####7      |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ####8      |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ####9      |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ####9      |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #####      |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #####1     |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #####2     |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #####3     |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #####4     |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #####4     |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #####5     |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #####6     |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #####7     |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #####8     |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #####9     |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ######     |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ######1    |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ######2    |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ######3    |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ######3    |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ######4    |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ######5    |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ######6    |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ######7    |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ######8    |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ######8    |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ######9    |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #######    |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #######    |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #######1   |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #######2   |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #######3   |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #######4   |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #######5   |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #######6   |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #######7   |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #######8   |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #######9   |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ########   |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ########1  |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ########2  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ########3  |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ########4  |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ########5  |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ########6  |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ########7  |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ########8  |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ########9  |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #########  |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #########1 |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ########## | 100%
#
#
#
#
# icu-70.1             | 17.0 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %% [markdown]
# If you have trouble with the above installation, try the simpler `pip install gymnasium` or `conda install -c conda-forge gymnasium` command (which does not install all of the dependencies that may only be needed for specific environments).

# %% [markdown]
# You can check that the installation was successful by running the following code. The code attempts to import the gymnasium module, create a simple [Taxi environment](https://gymnasium.farama.org/environments/toy_text/taxi/), and then execute random actions in the environment.
#
# The environment is set to `render_mode="human"`, meaning you should see a visualization of the environment with the agent taking random actions. Be aware that the visualization can be unstable on some platforms -- in particular, if your Python Kernel crashes after closing the visualization, that will not prevent you from completing the assignment (but is a good indication that you should save your learned Q tables/networks before rendering a visualization so that you don't lose any work).

# %%
import gymnasium as gym

# Initialise the environment
env = gym.make("Taxi-v3", render_mode="human")

# Reset the environment to generate the first observation
observation, info = env.reset()
for _ in range(100):
    # this is where you would insert your policy
    action = env.action_space.sample()

    # step (transition) through the environment with the action
    # receiving the next observation, reward and if the episode has terminated or truncated
    observation, reward, terminated, truncated, info = env.step(action)

    # If the episode has ended then we can reset to start a new episode
    if terminated or truncated:
        observation, info = env.reset()

env.close()

# %% [markdown]
# Next you should review the [Gymnasium Basic Usage Documentation](https://gymnasium.farama.org/introduction/basic_usage/) (through the Action and observation spaces section; you do not need to worry about the section on Modifying the environment). It may also be helpful to review or refer to the [Environment API documentation here](https://gymnasium.farama.org/api/env/).

# %% [markdown]
# ## Task 1
#
# Your first task is to define a **tabular** Q-learning agent for the simple [Taxi Environment](https://gymnasium.farama.org/environments/toy_text/taxi/). You should refer to the environment documentation to understand the state/observation space, action space, and reward function.
#
# Your agent `class` should implement at least the following three methods:
# 1. The constructor, `__init__()`, should should store any relevant hyperparameters as instance variables and initialize a Q table, along with any other auxiliary instance variables you may choose to include.
# 2. The `action_select` method which should implement `epsilon` greedy action selection (`epsilon` should be an instance variable kept track of by the agent object).
# 3. The `update` method should take an environment experience (previous state, action taken, reward received, new state, and whether the episode terminated) as input and should perform a Q learning update on the Q table.
#
#  You are welcome but not required to add additional helper methods.

# %%
class TaxiAgent:
    """
    Implements a tabular q learning agent for the taxi 
    environment with discrete states and actions.
    """
    def __init__(self, env, lr=0.01, discount=0.99,
                 epsilon_init=1.0, epsilon_final=0.05,
                 epsilon_decay=0.99):
        # todo: complete constructor/initialization
        pass # remove pass when implementing


    def action_select(self, s):
        # todo: complete epsilon greedy action selection
        pass # remove pass when implementing


    def update(self, s_old, a, r, s_new, terminated):
        # todo: complete Q learning update
        pass # remove pass when implementing

# %% [markdown]
# ## Task 2
#
# Now that you have defined your learning agent, implement a training loop over several episodes of experience with the environment. Your goal is to learn an optimal q function and corresponding policy (in the Taxi environment, that just implies efficiently picking up and delivering passengers to their appropriate destimations).
#
# Practically speaking, you should be able to learn a policy that achieves an average/expected episode return (cumulative reward) of approximately 0 (because the agent receives 20 reward for a correct dropoff, and -1 for each timestep, and it will require 10-20 timesteps on average to complete a pickup and dropoff). To accomplish this you may need to experiment with several of the key hyperparameters for the learning agent.
#
# While you are not required, you are encouraged to print periodic evaluation information during training (for example, every 100 or so episodes you may wish to printout the average return of the last 100 episodes) in order to track progress.
#
# Training should be quick on this environment: You should be able to learn an essentially optimal policy within several hundred or a few thousand episodes requiring only a few seconds of time.

# %%
# Initialise the environment
import gymnasium as gym

# todo: adjust n_episodes as needed for training
# default value of 100 for prototyping, will likely
# want more episodes for training
n_episodes = 100

env = gym.make("Taxi-v3")

# wrapper saves episode information necessary for later evaluation in task 3
env = gym.wrappers.RecordEpisodeStatistics(env, buffer_length = n_episodes)

# todo: environment loop with Q learning

# %% [markdown]
# ## Task 3
#
# After training, you can use the `visualize_learning_curves` function below to create two plots: One of the moving average episode return over the course of training and another of the moving average episode length over the course of training. A `smoothing` parameter to the function determines how many episodes to average over. That is, the default of `smoothing=10` means that each point in the resulting figure is the average of ten episodes. This has the visual effect of *smoothing* out the appearance of the plot, which can make the overall trend easier to visualize even if individual episodes vary significantly.
#
# Create visualizations of your learning curves. You should see improving performance on average episode return converging toward approximately zero.

# %%
# Run, but you do not need to modify this code

import numpy as np
from matplotlib import pyplot as plt

def visualize_learning_curves(env, smoothing=10):
    fig, axs = plt.subplots(1, 2, figsize=(20, 8))

    axs[0].plot(np.convolve(env.return_queue, np.ones(smoothing), 'valid') / smoothing)
    axs[0].set_title("Episode Returns", fontsize=20)
    axs[0].set_xlabel("Episode", fontsize=20)
    axs[0].set_ylabel("Return", fontsize=20)

    axs[1].plot(np.convolve(env.length_queue, np.ones(smoothing), 'valid') / smoothing)
    axs[1].set_title("Episode Lengths", fontsize=20)
    axs[1].set_xlabel("Episode", fontsize=20)
    axs[1].set_ylabel("Length", fontsize=20)

    plt.tight_layout()
    plt.show()

# %%
# todo: visualize learning curves

# %% [markdown]
# ## Optional
#
# The above evaluation of the learning curve was purely quantiative. While you are not required, you are invited and encouraged to qualitatively evaluate your learned policy/agent visually below. To do so, render the environment in `"human"` mode as shown below. This should render the visualization of the environment. Write a standard environment loop over several episodes (but far fewer than used for training, perhaps just 5 or so), and use the trained agent for action selection. For this evaluation purpose, you are welcome to set `epsilon` to a lower value or even 0, and you do not need to perform learning updates.
#
# Again, be aware that the visualization can be unstable on some platforms -- in particular, if your Python Kernel crashes after closing the visualization, that will not prevent you from completing the assignment (but is a good indication that you should save your learned Q tables/networks before rendering a visualization so that you don't lose any work).

# %%
# Initialise the environment
env = gym.make("Taxi-v3", render_mode="human")

# optional todo: environment loop to visualize learned policy
