# %% [markdown]
# # Part 1: Tabular Q-Learning
#
# In this part of the assignment you will familiarize yourself with the [Gymnasium API](https://gymnasium.farama.org/) for reinforcement learning and implement a tabular Q-learning agent to learn a behavioral policy in the simple [Taxi environment](https://gymnasium.farama.org/environments/toy_text/taxi/). This is intended as a warmup on a relatively small and simple task, preparing for a more challenging deep reinforcement learning task in part 2.
#
# **Learning objectives.** You will:
# 1. Install and study the standard Gymnasium API for representing a reinforcement learning environment simulation
# 2. Implement the tabular Q-learning algorithm with epsilon greedy action selection
# 3. Train an agent / compute an optimal q function and policy, experimenting with various hyperparameters like the learning rate and exploration decay
# 4. Evaluate the learning curve of average episodic return over training

# %% [markdown]
# We will use the [Gymnasium API](https://gymnasium.farama.org/) for our reinforcement learning environments. First you should run one of the following to install the necessary packages (either using `pip` or `conda` depending on your preferred Python package manager).

# %%
pip install "gymnasium[all]"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gymnasium[all]
#   Obtaining dependency information for gymnasium[all] from https://files.pythonhosted.org/packages/de/85/f5039ce2df5f0789ff1240f08a59f3e8c92e4c5f99543b7aad7388532f7c/gymnasium-1.0.0-py3-none-any.whl.metadata
#   Downloading gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from gymnasium[all]) (1.23.5)
# Collecting cloudpickle>=1.2.0 (from gymnasium[all])
#   Obtaining dependency information for cloudpickle>=1.2.0 from https://files.pythonhosted.org/packages/48/41/e1d85ca3cab0b674e277c8c4f678cf66a91cd2cecf93df94353a606fe0db/cloudpickle-3.1.0-py3-none-any.whl.metadata
#   Downloading cloudpickle-3.1.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from gymnasium[all]) (4.7.1)
# Collecting farama-notifications>=0.0.1 (from gymnasium[all])
#   Obtaining dependency information for farama-notifications>=0.0.1 from https://files.pythonhosted.org/packages/05/2c/ffc08c54c05cdce6fbed2aeebc46348dbe180c6d2c541c7af7ba0aa5f5f8/Farama_Notifications-0.0.4-py3-none-any.whl.metadata
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting ale-py>=0.9 (from gymnasium[all])
#   Obtaining dependency information for ale-py>=0.9 from https://files.pythonhosted.org/packages/a6/a1/adcc29a2162364046de02c49e65310894c99fd623c1ca871ec1bff082e25/ale_py-0.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading ale_py-0.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.6 kB)
# Collecting box2d-py==2.3.5 (from gymnasium[all])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 6.9 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting pygame>=2.1.3 (from gymnasium[all])
#   Obtaining dependency information for pygame>=2.1.3 from https://files.pythonhosted.org/packages/7a/a1/9ae2852ebd3a7cc7d9ae7ff7919ab983e4a5c1b7a14e840732f23b2b48f6/pygame-2.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pygame-2.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting swig==4.* (from gymnasium[all])
#   Obtaining dependency information for swig==4.* from https://files.pythonhosted.org/packages/11/56/b3503019d00b2cd8bb8e770cc7ac8108a1dfba8d38fc4d16c4259d7ea914/swig-4.3.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata
#   Downloading swig-4.3.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (3.5 kB)
# Collecting mujoco-py<2.2,>=2.1 (from gymnasium[all])
#   Obtaining dependency information for mujoco-py<2.2,>=2.1 from https://files.pythonhosted.org/packages/37/e5/e7504cb2ded511910c2a2e8f9c9e28af075850eb03a5c5a8daee5d7d9517/mujoco_py-2.1.2.14-py3-none-any.whl.metadata
#   Downloading mujoco_py-2.1.2.14-py3-none-any.whl.metadata (669 bytes)
# Collecting cython<3 (from gymnasium[all])
#   Obtaining dependency information for cython<3 from https://files.pythonhosted.org/packages/22/99/2b01e0164ff1ea592e3515e473517674780f0f3d49f48af30324b85ac94d/Cython-0.29.37-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata
#   Downloading Cython-0.29.37-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (3.1 kB)
# Collecting mujoco>=2.1.5 (from gymnasium[all])
#   Obtaining dependency information for mujoco>=2.1.5 from https://files.pythonhosted.org/packages/24/88/9b62960bd86a363d2e755f7b5d16ce6c20662afba685553ba1be40c82f8d/mujoco-3.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading mujoco-3.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 5.3 MB/s eta 0:00:00
# Collecting imageio>=2.14.1 (from gymnasium[all])
#   Obtaining dependency information for imageio>=2.14.1 from https://files.pythonhosted.org/packages/5c/f9/f78e7f5ac8077c481bf6b43b8bc736605363034b3d5eb3ce8eb79f53f5f1/imageio-2.36.1-py3-none-any.whl.metadata
#   Downloading imageio-2.36.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting jax>=0.4.0 (from gymnasium[all])
#   Obtaining dependency information for jax>=0.4.0 from https://files.pythonhosted.org/packages/62/20/6c57c50c0ccc645fea1895950f1e5cd02f961ee44b3ffe83617fa46b0c1d/jax-0.4.35-py3-none-any.whl.metadata
#   Downloading jax-0.4.35-py3-none-any.whl.metadata (22 kB)
# Collecting jaxlib>=0.4.0 (from gymnasium[all])
#   Obtaining dependency information for jaxlib>=0.4.0 from https://files.pythonhosted.org/packages/c8/a6/1abe8d682d46cf2989f9c4928866ae80c30a54d607221a262cff8a5d9366/jaxlib-0.4.35-cp311-cp311-manylinux2014_x86_64.whl.metadata
#   Downloading jaxlib-0.4.35-cp311-cp311-manylinux2014_x86_64.whl.metadata (983 bytes)
# Collecting flax>=0.5.0 (from gymnasium[all])
#   Obtaining dependency information for flax>=0.5.0 from https://files.pythonhosted.org/packages/50/a2/daca2bc563e1fd53c33fbff1e33e84004639f7ad9e1a9a54370480a7780d/flax-0.10.2-py3-none-any.whl.metadata
#   Downloading flax-0.10.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from gymnasium[all]) (2.1.0)
# Collecting opencv-python>=3.0 (from gymnasium[all])
#   Obtaining dependency information for opencv-python>=3.0 from https://files.pythonhosted.org/packages/3f/a4/d2537f47fd7fcfba966bd806e3ec18e7ee1681056d4b0a9c8d983983e4d5/opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: matplotlib>=3.0 in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from gymnasium[all]) (3.8.0)
# Collecting moviepy>=1.0.0 (from gymnasium[all])
#   Obtaining dependency information for moviepy>=1.0.0 from https://files.pythonhosted.org/packages/00/7b/edcb99095b403906becbeb61539123e391b22ec418eb0954a34d39a0bc83/moviepy-2.1.1-py3-none-any.whl.metadata
#   Downloading moviepy-2.1.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting msgpack (from flax>=0.5.0->gymnasium[all])
#   Obtaining dependency information for msgpack from https://files.pythonhosted.org/packages/a8/a1/ad7b84b91ab5a324e707f4c9761633e357820b011a01e34ce658c1dda7cc/msgpack-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading msgpack-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Collecting optax (from flax>=0.5.0->gymnasium[all])
#   Obtaining dependency information for optax from https://files.pythonhosted.org/packages/5c/24/28d0bb21600a78e46754947333ec9a297044af884d360092eb8561575fe9/optax-0.2.4-py3-none-any.whl.metadata
#   Downloading optax-0.2.4-py3-none-any.whl.metadata (8.3 kB)
# Collecting orbax-checkpoint (from flax>=0.5.0->gymnasium[all])
#   Obtaining dependency information for orbax-checkpoint from https://files.pythonhosted.org/packages/b3/67/a175072cd7e5a215b12f39f4d9d891881a6220d75e30ae6480d05647bdf4/orbax_checkpoint-0.10.1-py3-none-any.whl.metadata
#   Downloading orbax_checkpoint-0.10.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting tensorstore (from flax>=0.5.0->gymnasium[all])
#   Obtaining dependency information for tensorstore from https://files.pythonhosted.org/packages/e3/3b/44b16c200637d4c55b5a26cb994af8b3af656d56dc277a761c1e1000ab97/tensorstore-0.1.69-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading tensorstore-0.1.69-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting rich>=11.1 (from flax>=0.5.0->gymnasium[all])
#   Obtaining dependency information for rich>=11.1 from https://files.pythonhosted.org/packages/19/71/39c7c0d87f8d4e6c020a393182060eaefeeae6c01dab6a84ec346f2567df/rich-13.9.4-py3-none-any.whl.metadata
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from flax>=0.5.0->gymnasium[all]) (6.0.1)
# Requirement already satisfied: pillow>=8.3.2 in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from imageio>=2.14.1->gymnasium[all]) (10.0.1)
# Collecting ml-dtypes>=0.4.0 (from jax>=0.4.0->gymnasium[all])
#   Obtaining dependency information for ml-dtypes>=0.4.0 from https://files.pythonhosted.org/packages/89/65/ffdbf3489b0ba2213674ea347fad3a11747be64d2d23d888f9e5abe80a18/ml_dtypes-0.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading ml_dtypes-0.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Collecting numpy>=1.21.0 (from gymnasium[all])
#   Obtaining dependency information for numpy>=1.21.0 from https://files.pythonhosted.org/packages/7a/f0/80811e836484262b236c684a75dfc4ba0424bc670e765afaa911468d9f39/numpy-2.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading numpy-2.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: opt-einsum in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from jax>=0.4.0->gymnasium[all]) (3.3.0)
# Requirement already satisfied: scipy>=1.10 in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from jax>=0.4.0->gymnasium[all]) (1.11.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[all]) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[all]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[all]) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[all]) (1.4.5)
#   Obtaining dependency information for numpy>=1.21.0 from https://files.pythonhosted.org/packages/3a/d0/edc009c27b406c4f9cbc79274d6e46d634d139075492ad055e3d68445925/numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[all]) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[all]) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[all]) (2.8.2)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from moviepy>=1.0.0->gymnasium[all]) (5.1.1)
# Collecting imageio_ffmpeg>=0.2.0 (from moviepy>=1.0.0->gymnasium[all])
#   Obtaining dependency information for imageio_ffmpeg>=0.2.0 from https://files.pythonhosted.org/packages/fe/44/c9e18a73dfd939b5b0ec843870ac72f1f6c17e31a03149b687a85465bff7/imageio_ffmpeg-0.5.1-py3-none-manylinux2010_x86_64.whl.metadata
#   Downloading imageio_ffmpeg-0.5.1-py3-none-manylinux2010_x86_64.whl.metadata (1.6 kB)
# Collecting proglog<=1.0.0 (from moviepy>=1.0.0->gymnasium[all])
#   Obtaining dependency information for proglog<=1.0.0 from https://files.pythonhosted.org/packages/8b/f5/cab5cf6a540c31f5099043de0ae43990fd9cf66f75ecb5e9f254a4e4d4ee/proglog-0.1.10-py3-none-any.whl.metadata
#   Downloading proglog-0.1.10-py3-none-any.whl.metadata (639 bytes)
# Collecting python-dotenv>=0.10 (from moviepy>=1.0.0->gymnasium[all])
#   Obtaining dependency information for python-dotenv>=0.10 from https://files.pythonhosted.org/packages/6a/3e/b68c118422ec867fa7ab88444e1274aa40681c606d59ac27de5a5588f082/python_dotenv-1.0.1-py3-none-any.whl.metadata
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: absl-py in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from mujoco>=2.1.5->gymnasium[all]) (1.4.0)
# Collecting etils[epath] (from mujoco>=2.1.5->gymnasium[all])
#   Obtaining dependency information for etils[epath] from https://files.pythonhosted.org/packages/4f/4a/ff8aa2c57300613b69905308c5afe92c5b01112d766c25a305fd6796170a/etils-1.11.0-py3-none-any.whl.metadata
#   Downloading etils-1.11.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting glfw (from mujoco>=2.1.5->gymnasium[all])
#   Obtaining dependency information for glfw from https://files.pythonhosted.org/packages/bb/55/a513de61cafe6bd70c064a5b714dc084120fe8f90a5ba51fbc5cfe42fc13/glfw-2.8.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl.metadata
#   Downloading glfw-2.8.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Collecting pyopengl (from mujoco>=2.1.5->gymnasium[all])
#   Obtaining dependency information for pyopengl from https://files.pythonhosted.org/packages/99/48/00e31747821d3fc56faddd00a4725454d1e694a8b67d715cf20f531506a5/PyOpenGL-3.1.7-py3-none-any.whl.metadata
#   Downloading PyOpenGL-3.1.7-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: cffi>=1.10 in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from mujoco-py<2.2,>=2.1->gymnasium[all]) (1.15.1)
# Collecting fasteners~=0.15 (from mujoco-py<2.2,>=2.1->gymnasium[all])
#   Obtaining dependency information for fasteners~=0.15 from https://files.pythonhosted.org/packages/61/bf/fd60001b3abc5222d8eaa4a204cd8c0ae78e75adc688f33ce4bf25b7fafa/fasteners-0.19-py3-none-any.whl.metadata
#   Downloading fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: filelock in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from torch>=1.0.0->gymnasium[all]) (3.9.0)
# Requirement already satisfied: sympy in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from torch>=1.0.0->gymnasium[all]) (1.11.1)
# Requirement already satisfied: networkx in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from torch>=1.0.0->gymnasium[all]) (3.1)
# Requirement already satisfied: jinja2 in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from torch>=1.0.0->gymnasium[all]) (3.1.2)
# Requirement already satisfied: fsspec in /home/users/mll80/.local/lib/python3.11/site-packages (from torch>=1.0.0->gymnasium[all]) (2024.9.0)
# Requirement already satisfied: pycparser in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from cffi>=1.10->mujoco-py<2.2,>=2.1->gymnasium[all]) (2.21)
# Requirement already satisfied: setuptools in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from imageio_ffmpeg>=0.2.0->moviepy>=1.0.0->gymnasium[all]) (68.0.0)
# Requirement already satisfied: tqdm in /home/users/mll80/.local/lib/python3.11/site-packages (from proglog<=1.0.0->moviepy>=1.0.0->gymnasium[all]) (4.67.0)
# Requirement already satisfied: six>=1.5 in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->gymnasium[all]) (1.16.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=11.1->flax>=0.5.0->gymnasium[all])
#   Obtaining dependency information for markdown-it-py>=2.2.0 from https://files.pythonhosted.org/packages/42/d7/1ec15b46af6af88f19b8e5ffea08fa375d433c998b8a7639e76935c14f1f/markdown_it_py-3.0.0-py3-none-any.whl.metadata
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from rich>=11.1->flax>=0.5.0->gymnasium[all]) (2.15.1)
# Collecting importlib_resources (from etils[epath]->mujoco>=2.1.5->gymnasium[all])
#   Obtaining dependency information for importlib_resources from https://files.pythonhosted.org/packages/e1/6a/4604f9ae2fa62ef47b9de2fa5ad599589d28c9fd1d335f32759813dfa91e/importlib_resources-6.4.5-py3-none-any.whl.metadata
#   Downloading importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting zipp (from etils[epath]->mujoco>=2.1.5->gymnasium[all])
#   Obtaining dependency information for zipp from https://files.pythonhosted.org/packages/b7/1a/7e4798e9339adc931158c9d69ecc34f5e6791489d469f5e50ec15e35f458/zipp-3.21.0-py3-none-any.whl.metadata
#   Downloading zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from jinja2->torch>=1.0.0->gymnasium[all]) (2.1.1)
# Collecting chex>=0.1.87 (from optax->flax>=0.5.0->gymnasium[all])
#   Obtaining dependency information for chex>=0.1.87 from https://files.pythonhosted.org/packages/46/dd/c1ff2eb8fbf95a8ca804abb1cc3ce70b283ee7b4bc653c3abac245670400/chex-0.1.87-py3-none-any.whl.metadata
#   Downloading chex-0.1.87-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: nest_asyncio in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (1.5.6)
# Requirement already satisfied: protobuf in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (3.20.3)
# Collecting humanize (from orbax-checkpoint->flax>=0.5.0->gymnasium[all])
#   Obtaining dependency information for humanize from https://files.pythonhosted.org/packages/92/75/4bc3e242ad13f2e6c12e0b0401ab2c5e5c6f0d7da37ec69bc808e24e0ccb/humanize-4.11.0-py3-none-any.whl.metadata
#   Downloading humanize-4.11.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting simplejson>=3.16.0 (from orbax-checkpoint->flax>=0.5.0->gymnasium[all])
#   Obtaining dependency information for simplejson>=3.16.0 from https://files.pythonhosted.org/packages/b7/d4/850948bcbcfe0b4a6c69dfde10e245d3a1ea45252f16a1e2308a3b06b1da/simplejson-3.19.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading simplejson-3.19.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: mpmath>=0.19 in /usr/pkg/miniconda-23.9.0/lib/python3.11/site-packages (from sympy->torch>=1.0.0->gymnasium[all]) (1.3.0)
# Collecting toolz>=0.9.0 (from chex>=0.1.87->optax->flax>=0.5.0->gymnasium[all])
#   Obtaining dependency information for toolz>=0.9.0 from https://files.pythonhosted.org/packages/03/98/eb27cc78ad3af8e302c9d8ff4977f5026676e130d28dd7578132a457170c/toolz-1.0.0-py3-none-any.whl.metadata
#   Downloading toolz-1.0.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.5.0->gymnasium[all])
#   Obtaining dependency information for mdurl~=0.1 from https://files.pythonhosted.org/packages/b3/38/89ba8ad64ae25be8de66a6d463314cf1eb366222074cfda9ee839c56a4b4/mdurl-0.1.2-py3-none-any.whl.metadata
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading swig-4.3.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 33.1 MB/s eta 0:00:0000:01
# Downloading ale_py-0.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 36.5 MB/s eta 0:00:0000:01
# Downloading cloudpickle-3.1.0-py3-none-any.whl (22 kB)
# Downloading Cython-0.29.37-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 34.9 MB/s eta 0:00:0000:01
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading flax-0.10.2-py3-none-any.whl (424 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 424.2/424.2 kB 36.9 MB/s eta 0:00:00
# Downloading imageio-2.36.1-py3-none-any.whl (315 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.4/315.4 kB 30.1 MB/s eta 0:00:00
# Downloading jax-0.4.35-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 45.4 MB/s eta 0:00:00:00:01
# Downloading jaxlib-0.4.35-cp311-cp311-manylinux2014_x86_64.whl (87.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.3/87.3 MB 9.4 MB/s eta 0:00:00:00:0100:01
# Downloading moviepy-2.1.1-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.5/123.5 kB 12.2 MB/s eta 0:00:00
# Downloading mujoco-3.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 44.3 MB/s eta 0:00:0000:01:00:01
# Downloading mujoco_py-2.1.2.14-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 46.6 MB/s eta 0:00:00:00:01
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 32.7 MB/s eta 0:00:0000:01:00:01
# Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 12.7 MB/s eta 0:00:0000:0100:01m
# Downloading pygame-2.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 40.4 MB/s eta 0:00:00:00:0100:01
# Downloading gymnasium-1.0.0-py3-none-any.whl (958 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 42.5 MB/s eta 0:00:00
# Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Downloading glfw-2.8.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 19.7 MB/s eta 0:00:00
# Downloading imageio_ffmpeg-0.5.1-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 26.9 MB/s eta 0:00:00:00:0100:01
# Downloading ml_dtypes-0.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 49.8 MB/s eta 0:00:00:00:0100:01
# Downloading proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 kB 23.9 MB/s eta 0:00:00
# Downloading msgpack-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (403 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 403.7/403.7 kB 31.6 MB/s eta 0:00:00
# Downloading optax-0.2.4-py3-none-any.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.2/319.2 kB 30.0 MB/s eta 0:00:00
# Downloading orbax_checkpoint-0.10.1-py3-none-any.whl (328 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.3/328.3 kB 28.5 MB/s eta 0:00:00
# Downloading tensorstore-0.1.69-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.5/17.5 MB 37.0 MB/s eta 0:00:00:00:0100:01
# Downloading PyOpenGL-3.1.7-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 48.4 MB/s eta 0:00:00:00:01
# Downloading chex-0.1.87-py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 kB 14.1 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 11.4 MB/s eta 0:00:00
# Downloading simplejson-3.19.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.7/144.7 kB 16.2 MB/s eta 0:00:00
# Downloading etils-1.11.0-py3-none-any.whl (165 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.4/165.4 kB 22.9 MB/s eta 0:00:00
# Downloading humanize-4.11.0-py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.1/128.1 kB 15.5 MB/s eta 0:00:00
# Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading toolz-1.0.0-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 7.8 MB/s eta 0:00:00
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp311-cp311-linux_x86_64.whl size=494879 sha256=d83852f0b0eca01b3dcbc254ab820cbbdd61a0d81df0220c0e8657cf3f28b910
#   Stored in directory: /home/users/mll80/.cache/pip/wheels/ab/f1/0c/d56f4a2bdd12bae0a0693ec33f2f0daadb5eb9753c78fa5308
# Successfully built box2d-py
# Installing collected packages: swig, pyopengl, glfw, farama-notifications, box2d-py, zipp, toolz, simplejson, python-dotenv, pygame, proglog, numpy, msgpack, mdurl, importlib_resources, imageio_ffmpeg, humanize, fasteners, etils, cython, cloudpickle, opencv-python, ml-dtypes, markdown-it-py, imageio, gymnasium, ale-py, tensorstore, rich, mujoco-py, moviepy, jaxlib, mujoco, jax, orbax-checkpoint, chex, optax, flax
#   WARNING: The scripts swig and swig4.0 are installed in '/home/users/mll80/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script dotenv is installed in '/home/users/mll80/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script f2py is installed in '/home/users/mll80/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts cygdb, cython and cythonize are installed in '/home/users/mll80/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown-it is installed in '/home/users/mll80/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts imageio_download_bin and imageio_remove_bin are installed in '/home/users/mll80/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires libclang>=13.0.0, which is not installed.
# tensorflow 2.12.0 requires tensorflow-io-gcs-filesystem>=0.23.1; platform_machine != "arm64" or platform_system != "Darwin", which is not installed.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.26.4 which is incompatible.
# Successfully installed ale-py-0.10.1 box2d-py-2.3.5 chex-0.1.87 cloudpickle-3.1.0 cython-0.29.37 etils-1.11.0 farama-notifications-0.0.4 fasteners-0.19 flax-0.10.2 glfw-2.8.0 gymnasium-1.0.0 humanize-4.11.0 imageio-2.36.1 imageio_ffmpeg-0.5.1 importlib_resources-6.4.5 jax-0.4.35 jaxlib-0.4.35 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.5.0 moviepy-2.1.1 msgpack-1.1.0 mujoco-3.2.5 mujoco-py-2.1.2.14 numpy-1.26.4 opencv-python-4.10.0.84 optax-0.2.4 orbax-checkpoint-0.10.1 proglog-0.1.10 pygame-2.6.1 pyopengl-3.1.7 python-dotenv-1.0.1 rich-13.9.4 simplejson-3.19.3 swig-4.3.0 tensorstore-0.1.69 toolz-1.0.0 zipp-3.21.0
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge gymnasium-all
# Out:
# Channels:
#  - conda-forge
#  - defaults
#  - nvidia
#  - pytorch
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: - warning  libmamba Added empty dependency for problem type SOLVER_RULE_UPDATE
# failed
#
# LibMambaUnsatisfiableError: Encountered problems while solving:
#   - cannot install both pin-1-1 and pin-1-1
#
# Could not solve for environment specs
# The following packages are incompatible
# └─ pin-1 is installable with the potential options
#    ├─ pin-1 1, which can be installed;
#    └─ pin-1 1 conflicts with any installable versions previously reported.
#
# Pins seem to be involved in the conflict. Currently pinned specs:
#  - python 3.11.* (labeled as 'pin-1')
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# If you have trouble with the above installation, try the simpler `pip install gymnasium` or `conda install -c conda-forge gymnasium` command (which does not install all of the dependencies that may only be needed for specific environments).

# %% [markdown]
# You can check that the installation was successful by running the following code. The code attempts to import the gymnasium module, create a simple [Taxi environment](https://gymnasium.farama.org/environments/toy_text/taxi/), and then execute random actions in the environment.
#
# The environment is set to `render_mode="human"`, meaning you should see a visualization of the environment with the agent taking random actions. Be aware that the visualization can be unstable on some platforms -- in particular, if your Python Kernel crashes after closing the visualization, that will not prevent you from completing the assignment (but is a good indication that you should save your learned Q tables/networks before rendering a visualization so that you don't lose any work).

# %%
import gymnasium as gym

# Initialise the environment
env = gym.make("Taxi-v3", render_mode="human")

# Reset the environment to generate the first observation
observation, info = env.reset()
for _ in range(100):
    # this is where you would insert your policy
    action = env.action_space.sample()

    # step (transition) through the environment with the action
    # receiving the next observation, reward and if the episode has terminated or truncated
    observation, reward, terminated, truncated, info = env.step(action)

    if terminated or truncated:
        observation, info = env.reset()

env.close()
# Out:
# error: XDG_RUNTIME_DIR not set in the environment.

# %% [markdown]
# Next you should review the [Gymnasium Basic Usage Documentation](https://gymnasium.farama.org/introduction/basic_usage/) (through the Action and observation spaces section; you do not need to worry about the section on Modifying the environment). It may also be helpful to review or refer to the [Environment API documentation here](https://gymnasium.farama.org/api/env/).

# %% [markdown]
# ## Task 1
#
# Your first task is to define a **tabular** Q-learning agent for the simple [Taxi Environment](https://gymnasium.farama.org/environments/toy_text/taxi/). You should refer to the environment documentation to understand the state/observation space, action space, and reward function.
#
# Your agent `class` should implement at least the following three methods:
# 1. The constructor, `__init__()`, should should store any relevant hyperparameters as instance variables and initialize a Q table, along with any other auxiliary instance variables you may choose to include.
# 2. The `action_select` method which should implement `epsilon` greedy action selection (`epsilon` should be an instance variable kept track of by the agent object).
# 3. The `update` method should take an environment experience (previous state, action taken, reward received, new state, and whether the episode terminated) as input and should perform a Q learning update on the Q table.
#
#  You are welcome but not required to add additional helper methods.

# %%
import numpy as np

class TaxiAgent:
    """
    Implements a tabular Q-learning agent for the taxi 
    environment with discrete states and actions.
    """
    def __init__(self, env, lr=0.01, discount=0.99,
                 epsilon_init=1.0, epsilon_final=0.05,
                 epsilon_decay=0.99):
        """
        Initialize the Q-learning agent.

        Args:
            env: The Taxi environment (to get action and state spaces).
            lr: Learning rate.
            discount: Discount factor (gamma).
            epsilon_init: Initial value for epsilon in epsilon-greedy policy.
            epsilon_final: Minimum value for epsilon.
            epsilon_decay: Factor by which epsilon decays after each step.
        """
        self.lr = lr
        self.discount = discount
        self.epsilon = epsilon_init
        self.epsilon_final = epsilon_final
        self.epsilon_decay = epsilon_decay
        self.state_space = env.observation_space.n  
        self.action_space = env.action_space.n  

        self.q_table = np.zeros((self.state_space, self.action_space))

    def action_select(self, s):
        """
        Select an action using epsilon-greedy policy.
        """
        if np.random.random() < self.epsilon:
            return np.random.randint(self.action_space)
        else:
            return np.argmax(self.q_table[s])

    def update(self, s_old, a, r, s_new, terminated):
        q_current = self.q_table[s_old, a]
        q_max_next = 0 if terminated else np.max(self.q_table[s_new])
        self.q_table[s_old, a] = q_current + self.lr * (r + self.discount * q_max_next - q_current)
        self.epsilon = max(self.epsilon_final, self.epsilon * self.epsilon_decay)

# %% [markdown]
# ## Task 2
#
# Now that you have defined your learning agent, implement a training loop over several episodes of experience with the environment. Your goal is to learn an optimal q function and corresponding policy (in the Taxi environment, that just implies efficiently picking up and delivering passengers to their appropriate destimations).
#
# Practically speaking, you should be able to learn a policy that achieves an average/expected episode return (cumulative reward) of approximately 0 (because the agent receives 20 reward for a correct dropoff, and -1 for each timestep, and it will require 10-20 timesteps on average to complete a pickup and dropoff). To accomplish this you may need to experiment with several of the key hyperparameters for the learning agent.
#
# While you are not required, you are encouraged to print periodic evaluation information during training (for example, every 100 or so episodes you may wish to printout the average return of the last 100 episodes) in order to track progress.
#
# Training should be quick on this environment: You should be able to learn an essentially optimal policy within several hundred or a few thousand episodes requiring only a few seconds of time.

# %%
import gymnasium as gym
import numpy as np

n_episodes = 1300 

env = gym.make("Taxi-v3")

env = gym.wrappers.RecordEpisodeStatistics(env, buffer_length=n_episodes)

agent = TaxiAgent(
    env, 
    lr=0.1, 
    discount=0.99, 
    epsilon_init=1.0, 
    epsilon_final=0.05, 
    epsilon_decay=0.995
)

returns = []  
steps_per_episode = []  
for episode in range(1, n_episodes + 1):
    state, info = env.reset()
    done = False
    total_reward = 0
    steps = 0

    while not done:
        action = agent.action_select(state)
        next_state, reward, terminated, truncated, info = env.step(action)
        agent.update(state, action, reward, next_state, terminated)
        state = next_state
        total_reward += reward
        steps += 1
        done = terminated or truncated

    returns.append(total_reward)
    steps_per_episode.append(steps)

    if episode % 100 == 0:
        avg_return = np.mean(returns[-100:])  
        avg_steps = np.mean(steps_per_episode[-100:])  
        print(
            f"Episode {episode}, "
            f"Average Return (last 100 episodes): {avg_return:.2f}, "
            f"Average Steps: {avg_steps:.2f}, "
            f"Epsilon: {agent.epsilon:.4f}"
        )
# Out:
# Episode 100, Average Return (last 100 episodes): -306.03, Average Steps: 187.32, Epsilon: 0.0500
# Episode 200, Average Return (last 100 episodes): -207.13, Average Steps: 156.85, Epsilon: 0.0500
# Episode 300, Average Return (last 100 episodes): -153.16, Average Steps: 119.80, Epsilon: 0.0500
# Episode 400, Average Return (last 100 episodes): -131.87, Average Steps: 108.98, Epsilon: 0.0500
# Episode 500, Average Return (last 100 episodes): -68.73, Average Steps: 65.13, Epsilon: 0.0500
# Episode 600, Average Return (last 100 episodes): -63.74, Average Steps: 60.35, Epsilon: 0.0500
# Episode 700, Average Return (last 100 episodes): -33.96, Average Steps: 41.82, Epsilon: 0.0500
# Episode 800, Average Return (last 100 episodes): -30.35, Average Steps: 37.31, Epsilon: 0.0500
# Episode 900, Average Return (last 100 episodes): -14.49, Average Steps: 28.74, Epsilon: 0.0500
# Episode 1000, Average Return (last 100 episodes): -10.84, Average Steps: 24.73, Epsilon: 0.0500
# Episode 1100, Average Return (last 100 episodes): -4.95, Average Steps: 20.91, Epsilon: 0.0500
# Episode 1200, Average Return (last 100 episodes): -0.62, Average Steps: 18.02, Epsilon: 0.0500
# Episode 1300, Average Return (last 100 episodes): 0.73, Average Steps: 16.76, Epsilon: 0.0500

# %% [markdown]
# ## Task 3
#
# After training, you can use the `visualize_learning_curves` function below to create two plots: One of the moving average episode return over the course of training and another of the moving average episode length over the course of training. A `smoothing` parameter to the function determines how many episodes to average over. That is, the default of `smoothing=10` means that each point in the resulting figure is the average of ten episodes. This has the visual effect of *smoothing* out the appearance of the plot, which can make the overall trend easier to visualize even if individual episodes vary significantly.
#
# Create visualizations of your learning curves. You should see improving performance on average episode return converging toward approximately zero.

# %%
# Run, but you do not need to modify this code

import numpy as np
from matplotlib import pyplot as plt

def visualize_learning_curves(env, smoothing=10):
    fig, axs = plt.subplots(1, 2, figsize=(20, 8))

    axs[0].plot(np.convolve(env.return_queue, np.ones(smoothing), 'valid') / smoothing)
    axs[0].set_title("Episode Returns", fontsize=20)
    axs[0].set_xlabel("Episode", fontsize=20)
    axs[0].set_ylabel("Return", fontsize=20)

    axs[1].plot(np.convolve(env.length_queue, np.ones(smoothing), 'valid') / smoothing)
    axs[1].set_title("Episode Lengths", fontsize=20)
    axs[1].set_xlabel("Episode", fontsize=20)
    axs[1].set_ylabel("Length", fontsize=20)

    plt.tight_layout()
    plt.show()

# %%
visualize_learning_curves(env, smoothing=10)

# %% [markdown]
# ## Optional
#
# The above evaluation of the learning curve was purely quantiative. While you are not required, you are invited and encouraged to qualitatively evaluate your learned policy/agent visually below. To do so, render the environment in `"human"` mode as shown below. This should render the visualization of the environment. Write a standard environment loop over several episodes (but far fewer than used for training, perhaps just 5 or so), and use the trained agent for action selection. For this evaluation purpose, you are welcome to set `epsilon` to a lower value or even 0, and you do not need to perform learning updates.
#
# Again, be aware that the visualization can be unstable on some platforms -- in particular, if your Python Kernel crashes after closing the visualization, that will not prevent you from completing the assignment (but is a good indication that you should save your learned Q tables/networks before rendering a visualization so that you don't lose any work).

# %%
# Initialise the environment
env = gym.make("Taxi-v3", render_mode="human")

# optional todo: environment loop to visualize learned policy
